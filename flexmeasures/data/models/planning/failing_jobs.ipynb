# %%
import csv
import json
import re

def parse_error(error_str):
    """Extract the core error message from the traceback"""
    lines = error_str.strip().split('\n')
    return lines[-1].strip() if lines else "No error message found"

def parse_kwargs(kwargs_str):
    """Parse kwargs string into a dictionary and extract key scheduling info"""
    # Replace single quotes with double quotes and None with null
    kwargs_str = kwargs_str.replace("'", '"').replace("None", "null")
    # Handle datetime and timedelta more robustly
    kwargs_str = re.sub(r'datetime\.datetime\((.*?)\)', r'"\1"', kwargs_str)
    kwargs_str = re.sub(r'datetime\.timedelta\((.*?)\)', r'"\1"', kwargs_str)
    
    try:
        kwargs = json.loads(kwargs_str)
    except json.JSONDecodeError as e:
        return {
            "raw": kwargs_str,
            "error": f"Failed to parse kwargs: {str(e)}"
        }
    
    # Extract key scheduling constraints into a structured format
    summary = {
        "asset_id": kwargs.get("asset_or_sensor", {}).get("id"),
        "start": kwargs.get("start"),
        "end": kwargs.get("end"),
        "resolution": kwargs.get("resolution"),
        "soc_at_start": kwargs.get("flex_model", {}).get("soc-at-start"),
        "soc_min": kwargs.get("flex_model", {}).get("soc-min"),
        "soc_max": kwargs.get("flex_model", {}).get("soc-max"),
        "soc_unit": kwargs.get("flex_model", {}).get("soc-unit"),
    }
    
    if "soc-minima" in kwargs.get("flex_model", {}):
        summary["soc_minima"] = kwargs["flex_model"]["soc-minima"]
    if "soc-maxima" in kwargs.get("flex_model", {}):
        summary["soc_maxima"] = kwargs["flex_model"]["soc-maxima"]
    if "consumption-capacity" in kwargs.get("flex_model", {}):
        summary["consumption_capacity"] = kwargs["flex_model"]["consumption-capacity"]
    if "production-capacity" in kwargs.get("flex_model", {}):
        summary["production_capacity"] = kwargs["flex_model"]["production-capacity"]
    
    return summary

def process_failed_jobs(csv_file):
    structured_data = []
    
    try:
        with open(csv_file, 'r', newline='') as f:
            reader = csv.reader(f)
            next(reader)  # Skip header
            
            for row_num, row in enumerate(reader, start=2):
                if len(row) != 6:
                    print(f"Skipping row {row_num}: Expected 6 columns, got {len(row)} - {row}")
                    continue
                
                job_id, error, kwargs, func_name, started_at, ended_at = row
                
                structured_job = {
                    "Job ID": job_id,
                    "Error": parse_error(error),
                    "Kwargs": parse_kwargs(kwargs),
                    "Function Name": func_name,
                    "Started At": started_at,
                    "Ended At": ended_at
                }
                structured_data.append(structured_job)
    except FileNotFoundError:
        print(f"Error: '{csv_file}' not found.")
        return []
    except Exception as e:
        print(f"Error reading CSV: {e}")
        return []
    
    return structured_data

def print_dict_with_newlines(data, indent=2):
    """Helper function to print dictionary with each key-value pair on a new line"""
    if isinstance(data, dict):
        for key, value in data.items():
            if isinstance(value, (dict, list)):
                print(f"{' ' * indent}{key}:")
                print_dict_with_newlines(value, indent + 2)
            else:
                print(f"{' ' * indent}{key}: {value}")
    elif isinstance(data, list):
        for i, item in enumerate(data):
            print(f"{' ' * indent}Item {i}:")
            print_dict_with_newlines(item, indent + 2)
    else:
        print(f"{' ' * indent}{data}")

def print_all_jobs_with_index(jobs):
    if not jobs:
        print("No jobs to display.")
        return
    
    for index, job in enumerate(jobs):
        print(f"\nJob Index: {index}")
        print(f"Job ID: {job['Job ID']}")
        print(f"Error: {job['Error']}")
        print(f"Function Name: {job['Function Name']}")
        print(f"Started At: {job['Started At']}")
        print(f"Ended At: {job['Ended At']}")
        print("Scheduling Constraints:")
        print_dict_with_newlines(job['Kwargs'])
        print("-" * 50)

if __name__ == "__main__":
    csv_file = 'failed_jobs.csv'
    jobs = process_failed_jobs(csv_file)
    print_all_jobs_with_index(jobs)
# Out:
# Job Index: 0
# Job ID: c08f782c-9dfb-4d62-90be-f359ed2a6c7a
# Error: flexmeasures.data.models.planning.exceptions.InfeasibleProblemException
# Function Name: flexmeasures.data.services.scheduling.make_schedule
# Started At: 2025-02-20 13:51:46.038200
# Ended At: 2025-02-20 13:51:47.062469
# Scheduling Constraints:
#   raw: {"asset_or_sensor": {"id": 262, "class": "Sensor"}, "scheduler_specs": null, "start": "2025, 2, 20, 15, 0, tzinfo=datetime.timezone("seconds=3600", "+0100""), "end": "2025, 2, 21, 15, 0, tzinfo=datetime.timezone("seconds=3600", "+0100""), "resolution": "seconds=900", "belief_time": null, "flex_model": {"soc-unit": "kWh", "soc-at-start": 8.0001, "soc-max": 65.001, "soc-min": 24.001}, "flex_context": {"consumption-price-sensor": 14, "production-price-sensor": 14}}
#   error: Failed to parse kwargs: Expecting ',' delimiter: line 1 column 134 (char 133)
# --------------------------------------------------
#
# Job Index: 1
# Job ID: c5140205-829b-44be-9ff9-b863f5fb4a30
# Error: flexmeasures.data.models.planning.exceptions.InfeasibleProblemException
# Function Name: flexmeasures.data.services.scheduling.make_schedule
# Started At: 2025-02-20 13:53:20.594154
# Ended At: 2025-02-20 13:53:24.553718
# Scheduling Constraints:
#   raw: {"asset_or_sensor": {"id": 110, "class": "Sensor"}, "scheduler_specs": null, "start": "2025, 2, 20, 14, 55, tzinfo=datetime.timezone("seconds=3600", "+0100""), "end": "2025, 2, 21, 17, 55, tzinfo=datetime.timezone("seconds=3600", "+0100""), "resolution": "seconds=300", "belief_time": null, "flex_model": {"soc-at-start": 15.34, "soc-unit": "kWh", "soc-min": 14.75, "soc-max": 59, "soc-minima": [{"start": "2025-02-20T07:30:00+01:00", "end": "2025-02-20T16:15:00+01:00", "value": 29.5}, {"start": "2025-02-27T14:50:00+01:00", "end": "2025-02-27T14:55:00+01:00", "value": 47.2}], "soc-maxima": [{"value": 47.2, "start": "2025-02-20T14:55:00+01:00", "end": "2025-02-27T14:55:00+01:00"}], "roundtrip-efficiency": 0.85, "consumption-capacity": [{"start": "2025-02-20T07:30:00+01:00", "end": "2025-02-20T16:15:00+01:00", "value": "0 W"}, {"start": "2025-02-20T16:15:00+01:00", "end": "2025-02-21T17:55:00+01:00", "value": "5937 W"}], "production-capacity": [{"start": "2025-02-20T07:30:00+01:00", "end": "2025-02-20T16:15:00+01:00", "value": "0 W"}, {"start": "2025-02-20T16:15:00+01:00", "end": "2025-02-21T17:55:00+01:00", "value": "5937 W"}]}, "flex_context": {"consumption-price-sensor": 129, "production-price-sensor": 130}}
#   error: Failed to parse kwargs: Expecting ',' delimiter: line 1 column 135 (char 134)
# --------------------------------------------------
#
# Job Index: 2
# Job ID: 28f0f6b3-e9b1-4555-8564-756635663f3e
# Error: flexmeasures.data.models.planning.exceptions.InfeasibleProblemException
# Function Name: flexmeasures.data.services.scheduling.make_schedule
# Started At: 2025-02-20 14:08:20.637388
# Ended At: 2025-02-20 14:08:24.529130
# Scheduling Constraints:
#   raw: {"asset_or_sensor": {"id": 110, "class": "Sensor"}, "scheduler_specs": null, "start": "2025, 2, 20, 15, 10, tzinfo=datetime.timezone("seconds=3600", "+0100""), "end": "2025, 2, 21, 18, 10, tzinfo=datetime.timezone("seconds=3600", "+0100""), "resolution": "seconds=300", "belief_time": null, "flex_model": {"soc-at-start": 15.34, "soc-unit": "kWh", "soc-min": 14.75, "soc-max": 59, "soc-minima": [{"start": "2025-02-20T07:30:00+01:00", "end": "2025-02-20T16:15:00+01:00", "value": 29.5}, {"start": "2025-02-27T15:05:00+01:00", "end": "2025-02-27T15:10:00+01:00", "value": 47.2}], "soc-maxima": [{"value": 47.2, "start": "2025-02-20T15:10:00+01:00", "end": "2025-02-27T15:10:00+01:00"}], "roundtrip-efficiency": 0.85, "consumption-capacity": [{"start": "2025-02-20T07:30:00+01:00", "end": "2025-02-20T16:15:00+01:00", "value": "0 W"}, {"start": "2025-02-20T16:15:00+01:00", "end": "2025-02-21T18:10:00+01:00", "value": "5937 W"}], "production-capacity": [{"start": "2025-02-20T07:30:00+01:00", "end": "2025-02-20T16:15:00+01:00", "value": "0 W"}, {"start": "2025-02-20T16:15:00+01:00", "end": "2025-02-21T18:10:00+01:00", "value": "5937 W"}]}, "flex_context": {"consumption-price-sensor": 129, "production-price-sensor": 130}}
#   error: Failed to parse kwargs: Expecting ',' delimiter: line 1 column 135 (char 134)
# --------------------------------------------------
#
# Job Index: 3
# Job ID: d4585649-c9d0-452f-b576-ecd37c0b2773
# Error: flexmeasures.data.models.planning.exceptions.InfeasibleProblemException
# Function Name: flexmeasures.data.services.scheduling.make_schedule
# Started At: 2025-02-20 14:23:20.680629
# Ended At: 2025-02-20 14:23:24.610202
# Scheduling Constraints:
#   raw: {"asset_or_sensor": {"id": 110, "class": "Sensor"}, "scheduler_specs": null, "start": "2025, 2, 20, 15, 25, tzinfo=datetime.timezone("seconds=3600", "+0100""), "end": "2025, 2, 21, 18, 25, tzinfo=datetime.timezone("seconds=3600", "+0100""), "resolution": "seconds=300", "belief_time": null, "flex_model": {"soc-at-start": 15.34, "soc-unit": "kWh", "soc-min": 14.75, "soc-max": 59, "soc-minima": [{"start": "2025-02-20T07:30:00+01:00", "end": "2025-02-20T16:15:00+01:00", "value": 29.5}, {"start": "2025-02-27T15:20:00+01:00", "end": "2025-02-27T15:25:00+01:00", "value": 47.2}], "soc-maxima": [{"value": 47.2, "start": "2025-02-20T15:25:00+01:00", "end": "2025-02-27T15:25:00+01:00"}], "roundtrip-efficiency": 0.85, "consumption-capacity": [{"start": "2025-02-20T07:30:00+01:00", "end": "2025-02-20T16:15:00+01:00", "value": "0 W"}, {"start": "2025-02-20T16:15:00+01:00", "end": "2025-02-21T18:25:00+01:00", "value": "5937 W"}], "production-capacity": [{"start": "2025-02-20T07:30:00+01:00", "end": "2025-02-20T16:15:00+01:00", "value": "0 W"}, {"start": "2025-02-20T16:15:00+01:00", "end": "2025-02-21T18:25:00+01:00", "value": "5937 W"}]}, "flex_context": {"consumption-price-sensor": 129, "production-price-sensor": 130}}
#   error: Failed to parse kwargs: Expecting ',' delimiter: line 1 column 135 (char 134)
# --------------------------------------------------
#
# Job Index: 4
# Job ID: 228f2be4-9ca5-4f24-876a-96371e9d1a1a
# Error: flexmeasures.data.models.planning.exceptions.InfeasibleProblemException
# Function Name: flexmeasures.data.services.scheduling.make_schedule
# Started At: 2025-02-20 14:38:20.669831
# Ended At: 2025-02-20 14:38:24.492954
# Scheduling Constraints:
#   raw: {"asset_or_sensor": {"id": 110, "class": "Sensor"}, "scheduler_specs": null, "start": "2025, 2, 20, 15, 40, tzinfo=datetime.timezone("seconds=3600", "+0100""), "end": "2025, 2, 21, 18, 40, tzinfo=datetime.timezone("seconds=3600", "+0100""), "resolution": "seconds=300", "belief_time": null, "flex_model": {"soc-at-start": 15.34, "soc-unit": "kWh", "soc-min": 14.75, "soc-max": 59, "soc-minima": [{"start": "2025-02-20T07:30:00+01:00", "end": "2025-02-20T16:15:00+01:00", "value": 29.5}, {"start": "2025-02-27T15:35:00+01:00", "end": "2025-02-27T15:40:00+01:00", "value": 47.2}], "soc-maxima": [{"value": 47.2, "start": "2025-02-20T15:40:00+01:00", "end": "2025-02-27T15:40:00+01:00"}], "roundtrip-efficiency": 0.85, "consumption-capacity": [{"start": "2025-02-20T07:30:00+01:00", "end": "2025-02-20T16:15:00+01:00", "value": "0 W"}, {"start": "2025-02-20T16:15:00+01:00", "end": "2025-02-21T18:40:00+01:00", "value": "5937 W"}], "production-capacity": [{"start": "2025-02-20T07:30:00+01:00", "end": "2025-02-20T16:15:00+01:00", "value": "0 W"}, {"start": "2025-02-20T16:15:00+01:00", "end": "2025-02-21T18:40:00+01:00", "value": "5937 W"}]}, "flex_context": {"consumption-price-sensor": 129, "production-price-sensor": 130}}
#   error: Failed to parse kwargs: Expecting ',' delimiter: line 1 column 135 (char 134)
# --------------------------------------------------
#
# Job Index: 5
# Job ID: 905503d0-a3fa-4998-8692-0e9835bb4c5c
# Error: flexmeasures.data.models.planning.exceptions.InfeasibleProblemException
# Function Name: flexmeasures.data.services.scheduling.make_schedule
# Started At: 2025-02-20 14:53:20.705792
# Ended At: 2025-02-20 14:53:24.508379
# Scheduling Constraints:
#   raw: {"asset_or_sensor": {"id": 110, "class": "Sensor"}, "scheduler_specs": null, "start": "2025, 2, 20, 15, 55, tzinfo=datetime.timezone("seconds=3600", "+0100""), "end": "2025, 2, 21, 18, 55, tzinfo=datetime.timezone("seconds=3600", "+0100""), "resolution": "seconds=300", "belief_time": null, "flex_model": {"soc-at-start": 15.34, "soc-unit": "kWh", "soc-min": 14.75, "soc-max": 59, "soc-minima": [{"start": "2025-02-20T07:30:00+01:00", "end": "2025-02-20T16:15:00+01:00", "value": 29.5}, {"start": "2025-02-27T15:50:00+01:00", "end": "2025-02-27T15:55:00+01:00", "value": 47.2}], "soc-maxima": [{"value": 47.2, "start": "2025-02-20T15:55:00+01:00", "end": "2025-02-27T15:55:00+01:00"}], "roundtrip-efficiency": 0.85, "consumption-capacity": [{"start": "2025-02-20T07:30:00+01:00", "end": "2025-02-20T16:15:00+01:00", "value": "0 W"}, {"start": "2025-02-20T16:15:00+01:00", "end": "2025-02-21T18:55:00+01:00", "value": "5937 W"}], "production-capacity": [{"start": "2025-02-20T07:30:00+01:00", "end": "2025-02-20T16:15:00+01:00", "value": "0 W"}, {"start": "2025-02-20T16:15:00+01:00", "end": "2025-02-21T18:55:00+01:00", "value": "5937 W"}]}, "flex_context": {"consumption-price-sensor": 129, "production-price-sensor": 130}}
#   error: Failed to parse kwargs: Expecting ',' delimiter: line 1 column 135 (char 134)
# --------------------------------------------------
#
# Job Index: 6
# Job ID: 981b2c4f-2ae5-4130-84d5-88e2e5951467
# Error: flexmeasures.data.models.planning.exceptions.InfeasibleProblemException
# Function Name: flexmeasures.data.services.scheduling.make_schedule
# Started At: 2025-02-20 15:08:20.683345
# Ended At: 2025-02-20 15:08:24.322785
# Scheduling Constraints:
#   raw: {"asset_or_sensor": {"id": 110, "class": "Sensor"}, "scheduler_specs": null, "start": "2025, 2, 20, 16, 10, tzinfo=datetime.timezone("seconds=3600", "+0100""), "end": "2025, 2, 21, 19, 10, tzinfo=datetime.timezone("seconds=3600", "+0100""), "resolution": "seconds=300", "belief_time": null, "flex_model": {"soc-at-start": 15.34, "soc-unit": "kWh", "soc-min": 14.75, "soc-max": 59, "soc-minima": [{"start": "2025-02-20T07:30:00+01:00", "end": "2025-02-20T16:15:00+01:00", "value": 29.5}, {"start": "2025-02-27T16:05:00+01:00", "end": "2025-02-27T16:10:00+01:00", "value": 47.2}], "soc-maxima": [{"value": 47.2, "start": "2025-02-20T16:10:00+01:00", "end": "2025-02-27T16:10:00+01:00"}], "roundtrip-efficiency": 0.85, "consumption-capacity": [{"start": "2025-02-20T07:30:00+01:00", "end": "2025-02-20T16:15:00+01:00", "value": "0 W"}, {"start": "2025-02-20T16:15:00+01:00", "end": "2025-02-21T19:10:00+01:00", "value": "5937 W"}], "production-capacity": [{"start": "2025-02-20T07:30:00+01:00", "end": "2025-02-20T16:15:00+01:00", "value": "0 W"}, {"start": "2025-02-20T16:15:00+01:00", "end": "2025-02-21T19:10:00+01:00", "value": "5937 W"}]}, "flex_context": {"consumption-price-sensor": 129, "production-price-sensor": 130}}
#   error: Failed to parse kwargs: Expecting ',' delimiter: line 1 column 135 (char 134)
# --------------------------------------------------
#
# Job Index: 7
# Job ID: 26e81220-fbcd-4f3d-b2c3-334f50ce9096
# Error: flexmeasures.data.models.planning.exceptions.InfeasibleProblemException
# Function Name: flexmeasures.data.services.scheduling.make_schedule
# Started At: 2025-02-22 10:37:55.140017
# Ended At: 2025-02-22 10:37:59.171871
# Scheduling Constraints:
#   raw: {"asset_or_sensor": {"id": 99, "class": "Sensor"}, "scheduler_specs": null, "start": "2025, 2, 22, 11, 40, tzinfo=datetime.timezone("seconds=3600", "+0100""), "end": "2025, 2, 23, 14, 40, tzinfo=datetime.timezone("seconds=3600", "+0100""), "resolution": "seconds=300", "belief_time": null, "flex_model": {"soc-at-start": 23.01, "soc-unit": "kWh", "soc-min": 11.8, "soc-max": 59, "soc-minima": [{"start": "2025-02-22T12:00:00+01:00", "end": "2025-02-22T13:00:00+01:00", "value": 41.3}, {"start": "2025-03-01T11:35:00+01:00", "end": "2025-03-01T11:40:00+01:00", "value": 47.2}], "soc-maxima": [{"value": 47.2, "start": "2025-02-22T11:40:00+01:00", "end": "2025-03-01T11:40:00+01:00"}], "roundtrip-efficiency": 0.85, "consumption-capacity": [{"start": "2025-02-22T11:40:00+01:00", "end": "2025-02-22T12:00:00+01:00", "value": "5700 W"}, {"start": "2025-02-22T12:00:00+01:00", "end": "2025-02-22T13:00:00+01:00", "value": "0 W"}, {"start": "2025-02-22T13:00:00+01:00", "end": "2025-02-23T14:40:00+01:00", "value": "5700 W"}], "production-capacity": [{"start": "2025-02-22T11:40:00+01:00", "end": "2025-02-22T12:00:00+01:00", "value": "5700 W"}, {"start": "2025-02-22T12:00:00+01:00", "end": "2025-02-22T13:00:00+01:00", "value": "0 W"}, {"start": "2025-02-22T13:00:00+01:00", "end": "2025-02-23T14:40:00+01:00", "value": "5700 W"}]}, "flex_context": {"consumption-price-sensor": 90, "production-price-sensor": 91}}
#   error: Failed to parse kwargs: Expecting ',' delimiter: line 1 column 134 (char 133)
# --------------------------------------------------
#
# Job Index: 8
# Job ID: 8879c34f-359a-46cf-9cd3-31069cc4862c
# Error: flexmeasures.data.models.planning.exceptions.InfeasibleProblemException
# Function Name: flexmeasures.data.services.scheduling.make_schedule
# Started At: 2025-02-22 10:52:54.987643
# Ended At: 2025-02-22 10:52:59.140113
# Scheduling Constraints:
#   raw: {"asset_or_sensor": {"id": 99, "class": "Sensor"}, "scheduler_specs": null, "start": "2025, 2, 22, 11, 55, tzinfo=datetime.timezone("seconds=3600", "+0100""), "end": "2025, 2, 23, 14, 55, tzinfo=datetime.timezone("seconds=3600", "+0100""), "resolution": "seconds=300", "belief_time": null, "flex_model": {"soc-at-start": 23.01, "soc-unit": "kWh", "soc-min": 11.8, "soc-max": 59, "soc-minima": [{"start": "2025-02-22T12:00:00+01:00", "end": "2025-02-22T13:00:00+01:00", "value": 41.3}, {"start": "2025-03-01T11:50:00+01:00", "end": "2025-03-01T11:55:00+01:00", "value": 47.2}], "soc-maxima": [{"value": 47.2, "start": "2025-02-22T11:55:00+01:00", "end": "2025-03-01T11:55:00+01:00"}], "roundtrip-efficiency": 0.85, "consumption-capacity": [{"start": "2025-02-22T11:55:00+01:00", "end": "2025-02-22T12:00:00+01:00", "value": "5700 W"}, {"start": "2025-02-22T12:00:00+01:00", "end": "2025-02-22T13:00:00+01:00", "value": "0 W"}, {"start": "2025-02-22T13:00:00+01:00", "end": "2025-02-23T14:55:00+01:00", "value": "5700 W"}], "production-capacity": [{"start": "2025-02-22T11:55:00+01:00", "end": "2025-02-22T12:00:00+01:00", "value": "5700 W"}, {"start": "2025-02-22T12:00:00+01:00", "end": "2025-02-22T13:00:00+01:00", "value": "0 W"}, {"start": "2025-02-22T13:00:00+01:00", "end": "2025-02-23T14:55:00+01:00", "value": "5700 W"}]}, "flex_context": {"consumption-price-sensor": 90, "production-price-sensor": 91}}
#   error: Failed to parse kwargs: Expecting ',' delimiter: line 1 column 134 (char 133)
# --------------------------------------------------
#
# Job Index:
00+01:00", "value": "4750 W"}]}, "flex_context": {"consumption-price-sensor": 58, "production-price-sensor": 70}}
#   error: Failed to parse kwargs: Expecting ',' delimiter: line 1 column 133 (char 132)
# --------------------------------------------------
#
# Job Index: 25
# Job ID: 91f06ffb-2df2-4b3a-b667-48e907b53f10
# Error: flexmeasures.data.models.planning.exceptions.InfeasibleProblemException
# Function Name: flexmeasures.data.services.scheduling.make_schedule
# Started At: 2025-02-22 14:13:14.052901
# Ended At: 2025-02-22 14:13:17.982267
# Scheduling Constraints:
#   raw: {"asset_or_sensor": {"id": 51, "class": "Sensor"}, "scheduler_specs": null, "start": "2025, 2, 22, 15, 15, tzinfo=datetime.timezone("seconds=3600", "+0100""), "end": "2025, 2, 23, 18, 15, tzinfo=datetime.timezone("seconds=3600", "+0100""), "resolution": "seconds=300", "belief_time": null, "flex_model": {"soc-at-start": 22.78, "soc-unit": "kWh", "soc-min": 6.8, "soc-max": 34, "soc-minima": [{"start": "2025-02-22T09:00:00+01:00", "end": "2025-02-22T17:00:00+01:00", "value": 27.2}, {"start": "2025-02-23T09:00:00+01:00", "end": "2025-02-23T17:00:00+01:00", "value": 27.2}, {"start": "2025-03-01T15:10:00+01:00", "end": "2025-03-01T15:15:00+01:00", "value": 27.2}], "soc-maxima": [{"value": 27.2, "start": "2025-02-22T15:15:00+01:00", "end": "2025-03-01T15:15:00+01:00"}], "roundtrip-efficiency": 0.85, "consumption-capacity": [{"start": "2025-02-22T09:00:00+01:00", "end": "2025-02-22T17:00:00+01:00", "value": "0 W"}, {"start": "2025-02-22T17:00:00+01:00", "end": "2025-02-23T09:00:00+01:00", "value": "4750 W"}, {"start": "2025-02-23T09:00:00+01:00", "end": "2025-02-23T17:00:00+01:00", "value": "0 W"}, {"start": "2025-02-23T17:00:00+01:00", "end": "2025-02-23T18:15:00+01:00", "value": "4750 W"}], "production-capacity": [{"start": "2025-02-22T09:00:00+01:00", "end": "2025-02-22T17:00:00+01:00", "value": "0 W"}, {"start": "2025-02-22T17:00:00+01:00", "end": "2025-02-23T09:00:00+01:00", "value": "4750 W"}, {"start": "2025-02-23T09:00:00+01:00", "end": "2025-02-23T17:00:00+01:00", "value": "0 W"}, {"start": "2025-02-23T17:00:00+01:00", "end": "2025-02-23T18:15:00+01:00", "value": "4750 W"}]}, "flex_context": {"consumption-price-sensor": 58, "production-price-sensor": 70}}
#   error: Failed to parse kwargs: Expecting ',' delimiter: line 1 column 134 (char 133)
# --------------------------------------------------
#
# Job Index: 26
# Job ID: 306835bf-498f-4a8b-8dab-b5a9f3e691c8
# Error: flexmeasures.data.models.planning.exceptions.InfeasibleProblemException
# Function Name: flexmeasures.data.services.scheduling.make_schedule
# Started At: 2025-02-22 14:28:17.054246
# Ended At: 2025-02-22 14:28:21.008071
# Scheduling Constraints:
# ...
# Started At: 2025-02-25 14:53:10.226754
# Ended At: 2025-02-25 14:53:14.389846
# Scheduling Constraints:
#   raw: {"asset_or_sensor": {"id": 51, "class": "Sensor"}, "scheduler_specs": null, "start": "2025, 2, 25, 15, 55, tzinfo=datetime.timezone("seconds=3600", "+0100""), "end": "2025, 2, 26, 18, 55, tzinfo=datetime.timezone("seconds=3600", "+0100""), "resolution": "seconds=300", "belief_time": null, "flex_model": {"soc-at-start": 17.34, "soc-unit": "kWh", "soc-min": 6.8, "soc-max": 34, "soc-minima": [{"start": "2025-02-25T08:00:00+01:00", "end": "2025-02-25T17:00:00+01:00", "value": 27.2}, {"start": "2025-02-26T08:00:00+01:00", "end": "2025-02-26T17:00:00+01:00", "value": 27.2}, {"start": "2025-03-04T15:50:00+01:00", "end": "2025-03-04T15:55:00+01:00", "value": 27.2}], "soc-maxima": [{"value": 27.2, "start": "2025-02-25T15:55:00+01:00", "end": "2025-03-04T15:55:00+01:00"}], "roundtrip-efficiency": 0.85, "consumption-capacity": [{"start": "2025-02-25T08:00:00+01:00", "end": "2025-02-25T17:00:00+01:00", "value": "0 W"}, {"start": "2025-02-25T17:00:00+01:00", "end": "2025-02-26T08:00:00+01:00", "value": "4750 W"}, {"start": "2025-02-26T08:00:00+01:00", "end": "2025-02-26T17:00:00+01:00", "value": "0 W"}, {"start": "2025-02-26T17:00:00+01:00", "end": "2025-02-26T18:55:00+01:00", "value": "4750 W"}], "production-capacity": [{"start": "2025-02-25T08:00:00+01:00", "end": "2025-02-25T17:00:00+01:00", "value": "0 W"}, {"start": "2025-02-25T17:00:00+01:00", "end": "2025-02-26T08:00:00+01:00", "value": "4750 W"}, {"start": "2025-02-26T08:00:00+01:00", "end": "2025-02-26T17:00:00+01:00", "value": "0 W"}, {"start": "2025-02-26T17:00:00+01:00", "end": "2025-02-26T18:55:00+01:00", "value": "4750 W"}]}, "flex_context": {"consumption-price-sensor": 58, "production-price-sensor": 70}}
#   error: Failed to parse kwargs: Expecting ',' delimiter: line 1 column 134 (char 133)
# --------------------------------------------------
#
# Job Index: 90
# Job ID: bea5fbf9-fefb-48b9-81df-f9cf82f968cb
# Error: Work-horse terminated unexpectedly; waitpid returned None;
# Function Name: flexmeasures.data.services.scheduling.make_schedule
# Started At: 2025-02-25 15:00:00.731693
# Ended At: 2025-02-25 15:04:01.343211
# Scheduling Constraints:
#   raw: {"asset_or_sensor": {"id": 262, "class": "Sensor"}, "scheduler_specs": null, "start": "2025, 2, 25, 16, 15, tzinfo=datetime.timezone("seconds=3600", "+0100""), "end": "2025, 2, 26, 16, 15, tzinfo=datetime.timezone("seconds=3600", "+0100""), "resolution": "seconds=900", "belief_time": null, "flex_model": {"soc-unit": "kWh", "soc-at-start": 43.35, "soc-max": 65.001, "soc-min": 24.001}, "flex_context": {"consumption-price-sensor": 14, "production-price-sensor": 14}}
#   error: Failed to parse kwargs: Expecting ',' delimiter: line 1 column 135 (char 134)
# --------------------------------------------------
#
# Job Index: 91
# Job ID: ad97a2b2-64f4-4b50-ae29-cadc50e754b0
# Error: flexmeasures.data.models.planning.exceptions.InfeasibleProblemException
# Function Name: flexmeasures.data.services.scheduling.make_schedule
# Started At: 2025-02-25 15:08:10.187308
# Ended At: 2025-02-25 15:08:13.896327
# Scheduling Constraints:
#   raw: {"asset_or_sensor": {"id": 51, "class": "Sensor"}, "scheduler_specs": null, "start": "2025, 2, 25, 16, 10, tzinfo=datetime.timezone("seconds=3600", "+0100""), "end": "2025, 2, 26, 19, 10, tzinfo=datetime.timezone("seconds=3600", "+0100""), "resolution": "seconds=300", "belief_time": null, "flex_model": {"soc-at-start": 17.34, "soc-unit": "kWh", "soc-min": 6.8, "soc-max": 34, "soc-minima": [{"start": "2025-02-25T08:00:00+01:00", "end": "2025-02-25T17:00:00+01:00", "value": 27.2}, {"start": "2025-02-26T08:00:00+01:00", "end": "2025-02-26T17:00:00+01:00", "value": 27.2}, {"start": "2025-03-04T16:05:00+01:00", "end": "2025-03-04T16:10:00+01:00", "value": 27.2}], "soc-maxima": [{"value": 27.2, "start": "2025-02-25T16:10:00+01:00", "end": "2025-03-04T16:10:00+01:00"}], "roundtrip-efficiency": 0.85, "consumption-capacity": [{"start": "2025-02-25T08:00:00+01:00", "end": "2025-02-25T17:00:00+01:00", "value": "0 W"}, {"start": "2025-02-25T17:00:00+01:00", "end": "2025-02-26T08:00:00+01:00", "value": "4750 W"}, {"start": "2025-02-26T08:00:00+01:00", "end": "2025-02-26T17:00:00+01:00", "value": "0 W"}, {"start": "2025-02-26T17:00:00+01:00", "end": "2025-02-26T19:10:00+01:00", "value": "4750 W"}], "production-capacity": [{"start": "2025-02-25T08:00:00+01:00", "end": "2025-02-25T17:00:00+01:00", "value": "0 W"}, {"start": "2025-02-25T17:00:00+01:00", "end": "2025-02-26T08:00:00+01:00", "value": "4750 W"}, {"start": "2025-02-26T08:00:00+01:00", "end": "2025-02-26T17:00:00+01:00", "value": "0 W"}, {"start": "2025-02-26T17:00:00+01:00", "end": "2025-02-26T19:10:00+01:00", "value": "4750 W"}]}, "flex_context": {"consumption-price-sensor": 58, "production-price-sensor": 70}}
#   error: Failed to parse kwargs: Expecting ',' delimiter: line 1 column 134 (char 133)
# --------------------------------------------------
#
# Job Index: 92
# Job ID: 2faa73c2-e6aa-4c6f-948d-a5f5d9568c6f
# Error: flexmeasures.data.models.planning.exceptions.InfeasibleProblemException
# Function Name: flexmeasures.data.services.scheduling.make_schedule
# Started At: 2025-02-25 15:23:10.306860
# Ended At: 2025-02-25 15:23:14.169175
# Scheduling Constraints:
#   raw: {"asset_or_sensor": {"id": 51, "class": "Sensor"}, "scheduler_specs": null, "start": "2025, 2, 25, 16, 25, tzinfo=datetime.timezone("seconds=3600", "+0100""), "end": "2025, 2, 26, 19, 25, tzinfo=datetime.timezone("seconds=3600", "+0100""), "resolution": "seconds=300", "belief_time": null, "flex_model": {"soc-at-start": 17.34, "soc-unit": "kWh", "soc-min": 6.8, "soc-max": 34, "soc-minima": [{"start": "2025-02-25T08:00:00+01:00", "end": "2025-02-25T17:00:00+01:00", "value": 27.2}, {"start": "2025-02-26T08:00:00+01:00", "end": "2025-02-26T17:00:00+01:00", "value": 27.2}, {"start": "2025-03-04T16:20:00+01:00", "end": "2025-03-04T16:25:00+01:00", "value": 27.2}], "soc-maxima": [{"value": 27.2, "start": "2025-02-25T16:25:00+01:00", "end": "2025-03-04T16:25:00+01:00"}], "roundtrip-efficiency": 0.85, "consumption-capacity": [{"start": "2025-02-25T08:00:00+01:00", "end": "2025-02-25T17:00:00+01:00", "value": "0 W"}, {"start": "2025-02-25T17:00:00+01:00", "end": "2025-02-26T08:00:00+01:00", "value": "4750 W"}, {"start": "2025-02-26T08:00:00+01:00", "end": "2025-02-26T17:00:00+01:00", "value": "0 W"}, {"start": "2025-02-26T17:00:00+01:00", "end": "2025-02-26T19:25:00+01:00", "value": "4750 W"}], "production-capacity": [{"start": "2025-02-25T08:00:00+01:00", "end": "2025-02-25T17:00:00+01:00", "value": "0 W"}, {"start": "2025-02-25T17:00:00+01:00", "end": "2025-02-26T08:00:00+01:00", "value": "4750 W"}, {"start": "2025-02-26T08:00:00+01:00", "end": "2025-02-26T17:00:00+01:00", "value": "0 W"}, {"start": "2025-02-26T17:00:00+01:00", "end": "2025-02-26T19:25:00+01:00", "value": "4750 W"}]}, "flex_context": {"consumption-price-sensor": 58, "production-price-sensor": 70}}
#   error: Failed to parse kwargs: Expecting ',' delimiter: line 1 column 134 (char 133)
# --------------------------------------------------
#
# Job Index: 93
# Job ID: 8907df97-670f-4a4f-975b-b7669f381f01
# Error: flexmeasures.data.models.planning.exceptions.InfeasibleProblemException
# Function Name: flexmeasures.data.services.scheduling.make_schedule
# Started At: 2025-02-25 15:38:10.281853
# Ended At: 2025-02-25 15:38:13.964621
# Scheduling Constraints:
#   raw: {"asset_or_sensor": {"id": 51, "class": "Sensor"}, "scheduler_specs": null, "start": "2025, 2, 25, 16, 40, tzinfo=datetime.timezone("seconds=3600", "+0100""), "end": "2025, 2, 26, 19, 40, tzinfo=datetime.timezone("seconds=3600", "+0100""), "resolution": "seconds=300", "belief_time": null, "flex_model": {"soc-at-start": 17.34, "soc-unit": "kWh", "soc-min": 6.8, "soc-max": 34, "soc-minima": [{"start": "2025-02-25T08:00:00+01:00", "end": "2025-02-25T17:00:00+01:00", "value": 27.2}, {"start": "2025-02-26T08:00:00+01:00", "end": "2025-02-26T17:00:00+01:00", "value": 27.2}, {"start": "2025-03-04T16:35:00+01:00", "end": "2025-03-04T16:40:00+01:00", "value": 27.2}], "soc-maxima": [{"value": 27.2, "start": "2025-02-25T16:40:00+01:00", "end": "2025-03-04T16:40:00+01:00"}], "roundtrip-efficiency": 0.85, "consumption-capacity": [{"start": "2025-02-25T08:00:00+01:00", "end": "2025-02-25T17:00:00+01:00", "value": "0 W"}, {"start": "2025-02-25T17:00:00+01:00", "end": "2025-02-26T08:00:00+01:00", "value": "4750 W"}, {"start": "2025-02-26T08:00:00+01:00", "end": "2025-02-26T17:00:00+01:00", "value": "0 W"}, {"start": "2025-02-26T17:00:00+01:00", "end": "2025-02-26T19:40:00+01:00", "value": "4750 W"}], "production-capacity": [{"start": "2025-02-25T08:00:00+01:00", "end": "2025-02-25T17:00:00+01:00", "value": "0 W"}, {"start": "2025-02-25T17:00:00+01:00", "end": "2025-02-26T08:00:00+01:00", "value": "4750 W"}, {"start": "2025-02-26T08:00:00+01:00", "end": "2025-02-26T17:00:00+01:00", "value": "0 W"}, {"start": "2025-02-26T17:00:00+01:00", "end": "2025-02-26T19:40:00+01:00", "value": "4750 W"}]}, "flex_context": {"consumption-price-sensor": 58, "production-price-sensor": 70}}
#   error: Failed to parse kwargs: Expecting ',' delimiter: line 1 column 134 (char 133)
# --------------------------------------------------
#
# Job Index: 94
# Job ID: 669dd1d2-26b8-48a7-8fd5-a88cbc906fb6
# Error: flexmeasures.data.models.planning.exceptions.InfeasibleProblemException
# Function Name: flexmeasures.data.services.scheduling.make_schedule
# Started At: 2025-02-25 15:53:10.284397
# Ended At: 2025-02-25 15:53:14.175666
# Scheduling Constraints:
#   raw: {"asset_or_sensor": {"id": 51, "class": "Sensor"}, "scheduler_specs": null, "start": "2025, 2, 25, 16, 55, tzinfo=datetime.timezone("seconds=3600", "+0100""), "end": "2025, 2, 26, 19, 55, tzinfo=datetime.timezone("seconds=3600", "+0100""), "resolution": "seconds=300", "belief_time": null, "flex_model": {"soc-at-start": 17.34, "soc-unit": "kWh", "soc-min": 6.8, "soc-max": 34, "soc-minima": [{"start": "2025-02-25T08:00:00+01:00", "end": "2025-02-25T17:00:00+01:00", "value": 27.2}, {"start": "2025-02-26T08:00:00+01:00", "end": "2025-02-26T17:00:00+01:00", "value": 27.2}, {"start": "2025-03-04T16:50:00+01:00", "end": "2025-03-04T16:55:00+01:00", "value": 27.2}], "soc-maxima": [{"value": 27.2, "start": "2025-02-25T16:55:00+01:00", "end": "2025-03-04T16:55:00+01:00"}], "roundtrip-efficiency": 0.85, "consumption-capacity": [{"start": "2025-02-25T08:00:00+01:00", "end": "2025-02-25T17:00:00+01:00", "value": "0 W"}, {"start": "2025-02-25T17:00:00+01:00", "end": "2025-02-26T08:00:00+01:00", "value": "4750 W"}, {"start": "2025-02-26T08:00:00+01:00", "end": "2025-02-26T17:00:00+01:00", "value": "0 W"}, {"start": "2025-02-26T17:00:00+01:00", "end": "2025-02-26T19:55:00+01:00", "value": "4750 W"}], "production-capacity": [{"start": "2025-02-25T08:00:00+01:00", "end": "2025-02-25T17:00:00+01:00", "value": "0 W"}, {"start": "2025-02-25T17:00:00+01:00", "end": "2025-02-26T08:00:00+01:00", "value": "4750 W"}, {"start": "2025-02-26T08:00:00+01:00", "end": "2025-02-26T17:00:00+01:00", "value": "0 W"}, {"start": "2025-02-26T17:00:00+01:00", "end": "2025-02-26T19:55:00+01:00", "value": "4750 W"}]}, "flex_context": {"consumption-price-sensor": 58, "production-price-sensor": 70}}
#   error: Failed to parse kwargs: Expecting ',' delimiter: line 1 column 134 (char 133)
# --------------------------------------------------
#
# Job Index: 95
# Job ID: e03836b2-62d9-47d0-8558-e3e27eddcb80
# Error: Work-horse terminated unexpectedly; waitpid returned None;
# Function Name: flexmeasures.data.services.scheduling.make_schedule
# Started At: 2025-02-25 16:00:00.749238
# Ended At: 2025-02-25 16:04:01.373180
# Scheduling Constraints:
#   raw: {"asset_or_sensor": {"id": 262, "class": "Sensor"}, "scheduler_specs": null, "start": "2025, 2, 25, 17, 15, tzinfo=datetime.timezone("seconds=3600", "+0100""), "end": "2025, 2, 26, 17, 15, tzinfo=datetime.timezone("seconds=3600", "+0100""), "resolution": "seconds=900", "belief_time": null, "flex_model": {"soc-unit": "kWh", "soc-at-start": 38.65, "soc-max": 65.001, "soc-min": 24.001}, "flex_context": {"consumption-price-sensor": 14, "production-price-sensor": 14}}
#   error: Failed to parse kwargs: Expecting ',' delimiter: line 1 column 135 (char 134)
# --------------------------------------------------
#
# Job Index: 96
# Job ID: 3b76baa2-031c-417a-9539-b6d582e65b19
# Error: rq.timeouts.JobTimeoutException: Task exceeded maximum timeout value (180 seconds)
# Function Name: flexmeasures.data.services.scheduling.make_schedule
# Started At: 2025-02-25 18:00:03.316624
# Ended At: 2025-02-25 18:03:15.787681
# Scheduling Constraints:
#   raw: {"asset_or_sensor": {"id": 262, "class": "Sensor"}, "scheduler_specs": null, "start": "2025, 2, 25, 19, 15, tzinfo=datetime.timezone("seconds=3600", "+0100""), "end": "2025, 2, 26, 19, 15, tzinfo=datetime.timezone("seconds=3600", "+0100""), "resolution": "seconds=900", "belief_time": null, "flex_model": {"soc-unit": "kWh", "soc-at-start": 32.1, "soc-max": 65.001, "soc-min": 24.001}, "flex_context": {"consumption-price-sensor": 14, "production-price-sensor": 14}}
#   error: Failed to parse kwargs: Expecting ',' delimiter: line 1 column 135 (char 134)
# --------------------------------------------------
#
# Job Index: 97
# Job ID: beb8e9c1-981c-4ad1-8dad-3dbced75b774
# Error: rq.timeouts.JobTimeoutException: Task exceeded maximum timeout value (180 seconds)
# Function Name: flexmeasures.data.services.scheduling.make_schedule
# Started At: 2025-02-25 18:45:00.820117
# Ended At: 2025-02-25 18:48:13.815394
# Scheduling Constraints:
#   raw: {"asset_or_sensor": {"id": 262, "class": "Sensor"}, "scheduler_specs": null, "start": "2025, 2, 25, 20, 0, tzinfo=datetime.timezone("seconds=3600", "+0100""), "end": "2025, 2, 26, 20, 0, tzinfo=datetime.timezone("seconds=3600", "+0100""), "resolution": "seconds=900", "belief_time": null, "flex_model": {"soc-unit": "kWh", "soc-at-start": 30.15, "soc-max": 65.001, "soc-min": 24.001}, "flex_context": {"consumption-price-sensor": 14, "production-price-sensor": 14}}
#   error: Failed to parse kwargs: Expecting ',' delimiter: line 1 column 134 (char 133)
# --------------------------------------------------
#
# Job Index: 98
# Job ID: c2ab7944-a3c3-4db1-891e-16cfcf463ef5
# Error: Work-horse terminated unexpectedly; waitpid returned None;
# Function Name: flexmeasures.data.services.scheduling.make_schedule
# Started At: 2025-02-25 19:45:03.778444
# Ended At: 2025-02-25 19:49:04.365451
# Scheduling Constraints:
#   raw: {"asset_or_sensor": {"id": 262, "class": "Sensor"}, "scheduler_specs": null, "start": "2025, 2, 25, 21, 0, tzinfo=datetime.timezone("seconds=3600", "+0100""), "end": "2025, 2, 26, 21, 0, tzinfo=datetime.timezone("seconds=3600", "+0100""), "resolution": "seconds=900", "belief_time": null, "flex_model": {"soc-unit": "kWh", "soc-at-start": 28.0, "soc-max": 65.001, "soc-min": 24.001}, "flex_context": {"consumption-price-sensor": 14, "production-price-sensor": 14}}
#   error: Failed to parse kwargs: Expecting ',' delimiter: line 1 column 134 (char 133)
# --------------------------------------------------
#
# Job Index: 99
# Job ID: 8abd8273-262e-490d-bf3b-fa689ba719e8
# Error: Work-horse terminated unexpectedly; waitpid returned None;
# Function Name: flexmeasures.data.services.scheduling.make_schedule
# Started At: 2025-02-25 20:00:04.807492
# Ended At: 2025-02-25 20:04:05.380196
# Scheduling Constraints:
#   raw: {"asset_or_sensor": {"id": 262, "class": "Sensor"}, "scheduler_specs": null, "start": "2025, 2, 25, 21, 15, tzinfo=datetime.timezone("seconds=3600", "+0100""), "end": "2025, 2, 26, 21, 15, tzinfo=datetime.timezone("seconds=3600", "+0100""), "resolution": "seconds=900", "belief_time": null, "flex_model": {"soc-unit": "kWh", "soc-at-start": 27.55, "soc-max": 65.001, "soc-min": 24.001}, "flex_context": {"consumption-price-sensor": 14, "production-price-sensor": 14}}
#   error: Failed to parse kwargs: Expecting ',' delimiter: line 1 column 135 (char 134)
# --------------------------------------------------
